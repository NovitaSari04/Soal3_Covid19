# %% [markdown]
# ### __Soal 3 - Indonesia Covid-19 Maps__

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Web Scraping Wikipedia
url = 'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Indonesia'
html = requests.get(url)
soup = BeautifulSoup(html.content, 'html.parser')

x = soup.find_all('tbody')
My_table = x[3].text

My_table = My_table.split('\n')
My_text = []
My_angka = []
for i in My_table:
    if len(i)>0:
        if i[0] in ['1','2', '3', '4', '5', '6', '7', '8', '9', '0']:
            My_angka.append(i)
        else:
            My_text.append(i)
            

dataConfirmed = My_angka[4:140:4]
dataRecovered = My_angka[5:140:4]
dataDeaths = My_angka[6:140:4]
dataActive = My_angka[7:140:4]

My_data = []
My_text2 = []
for i in My_text:
    if '.' in i:
        My_data.append(i)
    else :
        My_text2.append(i.replace('[b]',''))
dataProv = My_text2[6:40]

dfWiki = pd.DataFrame(list(zip(dataProv, dataConfirmed, dataRecovered, dataDeaths, dataActive,)), 
               columns =['Provinsi', 'Confirmed', 'Recovered', 'Deaths', 'Active'])
dfWiki
# Out:
#               Provinsi Confirmed Recovered Deaths Active
# 0                 Aceh         5         0      0      5
# 1                 Bali        10         0      2      8
# 2      Bangka Belitung         0         0      0      0
# 3               Banten       106         1      4    101
# 4             Bengkulu         0         0      0      0
# 5         Central Java        63         0      7     56
# 6   Central Kalimantan         7         0      0      7
# 7     Central Sulawesi         2         0      0      2
# 8            East Java        90        11      7     72
# 9      East Kalimantan        17         0      0     17
# 10  East Nusa Tenggara         0         0      0      0
# 11           Gorontalo         0         0      0      0
# 12             Jakarta       720        45     68    607
# 13               Jambi         1         0      0      1
# 14             Lampung         4         0      0      4
# ...

# %%
# GET API untuk Data Latitute dan Longitude
url2 = 'https://raw.githubusercontent.com/LintangWisesa/Indonesia-Covid19-Maps/master/data/gps_indonesia.json'
data = requests.get(url2)
hasil = data.json()
dfAPI = pd.DataFrame(hasil)
dfAPI
# Out:
#               Provinsi  latitude   longitude  \
# 0                 Aceh  4.695135   96.749399
# 1                 Bali -8.409518  115.188916
# 2      Bangka Belitung -2.741051  106.440587
# 3               Banten -6.405817  106.064018
# 4             Bengkulu -3.577847  102.346388
# 5         Central Java -7.150975  110.140259
# 6   Central Kalimantan -1.681488  113.382355
# 7     Central Sulawesi -1.430025  121.445618
# 8            East Java -7.536064  112.238402
# 9      East Kalimantan  1.640630  116.419389
# 10  East Nusa Tenggara -8.657382  121.079370
# 11           Gorontalo  0.699937  122.446724
# 12             Jakarta -6.211544  106.845172
# 13               Jambi -1.485183  102.438058
# 14             Lampung -4.558585  105.406808
# 15              Maluku -3.238462  130.145273
# 16        North Maluku  1.570999  127.808769
# 17    North Kalimantan  1.580213  114.030855
# 18      North Sulawesi  0.624693  123.975002
# 19      North Sumatera  2.115355   99.545097
# ...

# %%
# Membuat html interaktif
import folium as fo
peta = fo.Map(
    location = [-2.2756707, 116.4386513],
    tiles = 'OpenStreetMap',
    zoom_start = 4.6
)
for i in range(len(dfWiki)):
    fo.Marker(
        [dfAPI.iloc[i]['latitude'],dfAPI.iloc[i]['longitude']],
        popup = f"<b><h3> {dfWiki.iloc[i]['Provinsi']} </h3> </b> <br> Confirmed : {dfWiki.iloc[i]['Confirmed']} <br> Recovered : {dfWiki.iloc[i]['Recovered']}  <br>  Death : {dfWiki.iloc[i]['Deaths']}  <br>  Active: {dfWiki.iloc[i]['Active']}",
        icon = fo.features.CustomIcon(dfAPI['logo'][i],icon_size=(25, 30)),
        tooltip = 'Klik untuk detail kasus'
    ).add_to(peta)
    
peta.save('Soal3_Covid19.html')
peta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
